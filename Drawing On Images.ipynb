# %% [markdown]
# # Drawing on Images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.core.pylabtools import figsize
figsize(8, 8)

# %%
blank_img = np.zeros(shape=(512,512,3),dtype=np.int32)

# %%
blank_img.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(blank_img)

# %% [markdown]
# -----
# # Shapes
# ----

# %% [markdown]
# ### Rectangles
#
# * img Image.
# * pt1 Vertex of the rectangle.
# * pt2 Vertex of the rectangle opposite to pt1 .
# * color Rectangle color or brightness (grayscale image).
# * thickness Thickness of lines that make up the rectangle. Negative values, like #FILLED,mean that the function has to draw a filled rectangle.
# * lineType Type of the line. See #LineTypes
# * shift Number of fractional bits in the point coordinates.

# %%
# pt1 = top left
# pt2 = bottom right
cv2.rectangle(blank_img,pt1=(320,20),pt2=(490,128),color=(0,255,0),thickness = 6)
plt.imshow(blank_img)

# %% [markdown]
# Let's practice by drawing a blue rectangle in the middle of the image.

# %%
# pt1 = top left
# pt2 = bottom right
cv2.rectangle(blank_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=5)
plt.imshow(blank_img)

# %% [markdown]
# ## Circles

# %%
cv2.circle(img=blank_img, center=(100,100), radius=50, color=(255,0,0), thickness=5)
plt.imshow(blank_img)

# %% [markdown]
# ### Filled In

# %%
cv2.circle(img=blank_img, center=(400,400), radius=50, color=(255,255,0), thickness=-1)
plt.imshow(blank_img)

# %% [markdown]
# ### Lines

# %%
# Draw a diagonal blue line with thickness of 5 px
cv2.line(blank_img,pt1=(0,0),pt2=(511,511),color=(255, 0, 255),thickness=5)
cv2.line(blank_img,pt1=(511,0),pt2=(0,511),color=(0, 255, 255),thickness=5)
plt.imshow(blank_img)

# %% [markdown]
# ### Text

# %%
font = cv2.FONT_ITALIC
cv2.putText(blank_img,text='Hello',org=(10,500), fontFace=font,fontScale= 4,color=(255,255,255),thickness=6,lineType=cv2.LINE_AA)
plt.imshow(blank_img)

# %% [markdown]
# ### Polygons
#
# To draw a polygon, first you need coordinates of vertices. Make those points into an array of shape ROWSx1x2 where ROWS are number of vertices and it should be of type int32.

# %%
blank_img = np.zeros(shape=(512,512,3),dtype=np.int32)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],np.int32)

# %%
pts = vertices.reshape((-1,1,2))

# %%
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]])

# %%
cv2.polylines(blank_img,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(blank_img)
